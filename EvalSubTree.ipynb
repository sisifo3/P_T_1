# %% [markdown]
# <a href="https://colab.research.google.com/github/sisifo3/P_T_1/blob/main/EvalSubTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
#drive.mount('/content/drive')

# !cat '/content/drive/MyDrive/cond_p.py'
# !cat '/content/drive/MyDrive/take_d.py'

#!cat '/content/drive/MyDrive/Colab Notebooks/take_d.ipynb'
#!cat '/content/drive/MyDrive/Colab Notebooks/Cond_p.ipynb'

import sys
sys.path.append('/content/drive/MyDrive')
#sys.path.append('/content/drive/MyDrive/Colab Notebooks')
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import math
import random
import cond_p
import take_d

#Lo primero encontrar los nodos recolectores 
#la visita va a ser ordenada 

#vamos a dividir el problema en subproblemas 


def OrderDecisions(cpa,cpb,a):
  l = []
  c = [0]*2
  b = [0]*2
  b[0] = cpa
  b[1] = cpb
  print(b)
  print(a)
  #l.append(b)
  #l.append(a)
  #c = a
  #print(l)
  if b[1] > b[0]:
    c[0] = a[1]
    c[1] = a[0]
  else:
    c = a   
  #l.sort(key = lambda row: row[0])
  #print(l)
  return c





a = [13,3]
cpa = 0.2222222222222222 
cpb = 0.28125
c = OrderDecisions(cpa,cpb,a)
print(c)




def EvalSubTree(m):

  M = m
  a = take_d.OnlyValues(M)
  n = 1

  while (n != 0):
    n = len(a)
    #print(a)
    b = take_d.rand_n(n)
    print(M)
    if n > 1:
      cpa, cpb  = cond_p.Conditionalprobability(M)
      a = OrderDecisions(cpa,cpb,a)
      #print(cpa,cpb)
      #print(a)
    for i in range(n):
      c = b[i]
      d = a[i]
      X = M
      if c != 0:
        X = take_d.DeletedNodes(M,d)
      M = take_d.DeletedNode(X,d)
    a = take_d.OnlyValues(M)
    n = len(a)

m = [[19, 9, 4, 1, 0],
[19, 9, 4, 1],
[19, 9, 4, 1, 2],
[19, 9, 4, 1, 2, 3],
[19, 9, 4],
[19, 9, 4, 6, 5],
[19, 9, 4, 6],
[19, 9, 4, 6, 7],
[19, 9, 4, 6, 7, 8],
[19, 9],
[19, 9, 14, 11, 10],
[19, 9, 14, 11],
[19, 9, 14, 11, 12],
[19, 9, 14, 11, 12, 13],
[19, 9, 14],
[19, 9, 14, 16, 15],
[19, 9, 14, 16],
[19, 9, 14, 16, 17],
[19, 9, 14, 16, 17, 18],
[19],
[19, 29, 24, 21, 20],
[19, 29, 24, 21],
[19, 29, 24, 21, 22],
[19, 29, 24, 21, 22, 23],
[19, 29, 24],
[19, 29, 24, 26, 25],
[19, 29, 24, 26],
[19, 29, 24, 26, 27],
[19, 29, 24, 26, 27, 28],
[19, 29],
[19, 29, 34, 31, 30],
[19, 29, 34, 31],
[19, 29, 34, 31, 32],
[19, 29, 34, 31, 32, 33],
[19, 29, 34],
[19, 29, 34, 37, 35],
[19, 29, 34, 37, 35, 36],
[19, 29, 34, 37],
[19, 29, 34, 37, 38],
[19, 29, 34, 37, 38, 39]]
  
EvalSubTree(m)
