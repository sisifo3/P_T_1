# %% [markdown]
# <a href="https://colab.research.google.com/github/sisifo3/P_T_1/blob/main/mainBinaryV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este modelo busca convinar dos modelos mainBinary y mainBinaryV2, el primer algoritmo supone que existe una cadena de contagios entre los diferentes nodos, por ende siempre espera un postivo en el nodo principal(45) y solamente un caso.  El modelo 2 es similar al primero (comparten una gran cantidad de funciones), pero este supone que talvez el contagio aún no ha llegado al colector o al nodo 45, entonces, aúnque no identifique un nodo positivo, sale a buscar en los diferentes ramales, revisando por lo menos dos nodos, además de considerar la posibilidad de mas de un caso positivo

# %%
t = [0] * 46
t[42] = 0
t[40] = 0
t[41] = 0
t[44] = 0
t[43] = 0
t[37] = 0
t[38] = 0
t[39] = 0
t[10] = 0
t[12] = 0
t[11] = 0 
t[7] = 0
t[6] = 0
t[8] = 0
t[9] = 0
t[16] = 0
t[15] = 0
t[13] = 0
t[14] = 0


t[18] = 1
t[20] = 1
t[21] = 0
t[22] = 1
t[23] = 1
t[24] = 1
t[26] = 1
t[27] = 1
t[28] = 1
t[29] = 0
t[30] = 0
t[31] = 0
t[33] = 0
t[34] = 0
t[35] = 0
t[36] = 0
t[45] = 0


n1,d1 = BinarySearchColector(t)

if n1 == 46:
  n,d = callSearchpernode(t)
else:
  n,d = BinarySearch(t,n1)
   

print(n1,n)
print(d1,d)
# Out:
# 46 [0, 0, 22, 18, 0]
# [29, 45] [[43, 39], [33, 35], [26, 25, 24, 22], [16, 20, 18], [4, 9]]

# %%
#Buscamos la posibilidad de que existan mas de un nodo con contagio. 
#Si no existe en el colector visitamos dos por ramal. 

def callSearchpernode(t):
  
  #mainBinaryV2 


  def node5ABinarySearchO(t):
    #Esta funcion es busqueda lineal 
    sortCheck = [4,3,2,1]
    val_l = 6
    d = []
    n = 0

    if t[3] == 0 :
      #print("node 3")
      d.append(3)
      if t[4] == 0:
        #print("node 4")
        d.append(4)
        n=0
      elif t[4] == 1:
        #print("node 4")
        d.append(4)
        n = 4 
        if t[5] == 1:
          #print("node 5")
          d.append(5)
          n = 5
        elif t[5] == 0:
          #print("node 5")
          d.append(5)
          n = 4  

    elif t[3] == 1:
      #print("node 3")
      d.append(3)
      if t[1] == 1:
        #print("node 1")
        d.append(1)
        n = 1
      elif t[1] == 0:
        #print("node 1")
        d.append(1)
        if t[2] == 0:
          #print("node 2")
          d.append(2)
          n = 3
        if t[2] == 1:
          #print("node 2")
          d.append(2)
          n = 2


    return n,d


  #t= [0] * 46
  #t[1] = 0
  #t[2] = 0
  #t[3] = 0
  #t[4] = 0
  #sortCheck = [13,14,15,16,18,20]
  #n,d =  node5ABinarySearchO(t)
  #print("n",n)
  #print("d", d)


  ###############################################################################

  #####################################################################3

  def node5BBinarySearchO(t):
    #Esta funcion es busqueda lineal 
    sortCheck = [9,11,12]
    val_l = 6
    d = []
    n = 0


    if t[11] == 0:
      #print("node 1")
      d.append(11)
      if t[9] == 0:
        #print("node 9")
        d.append(9)
        n = 0
      elif t[9] == 1:
        #print("node 9")
        d.append(9)
        n = 9
        if t[7] == 0:
          #print("ndde 7 ")
          d.append(7)
          if t[8] == 0:
            #print("npde 8")
            d.append(8)
            n = 9
          elif t[8] == 1:
            #print("node 8")
            d.append(8)
            n = 8
        elif t[7] == 1:
          #print("node 7")
          d.append(7)
          n = 7     

    
    elif t[11] == 1:
      #print("node 11")
      d.append(11)
      if t[12] == 1:
        #print("node 12")
        d.append(12)
        n = 12
      elif t[12] == 0:
        #print("node 12")
        d.append(12)
        n = 11
        if t[10] == 1:
          #print("node 10")
          d.append(10)
          n = 10
        elif t[10] == 0:
          #print("node 10")
          d.append(10)
          n = 11 


    return n,d


  #t= [0] * 46
  #t[9] = 0
  #t[11] = 0
  #t[12] = 0
  #sortCheck = [13,14,15,16,18,20]
  #n,d =  node5BBinarySearchO(t)
  #print("n",n)
  #print("d", d)


  #############################################################################



  def node5BinarySearchO(t):
    #Esta funcion es busqueda lineal 
    sortCheck = [6,4,9]
    val_l = sortCheck[0]
    d = []
    n = 0
    if t[4] == 0:
      #print("node 4")
      d.append(4)
      if t[9] == 0:
        #print("node 9")
        d.append(9)
        n = 0
      elif t[9] ==1:
        #print("node 9")
        n,dB =  node5BBinarySearchO(t)
        d.append(dB)
    elif t[4] == 1:
      n,dA =  node5ABinarySearchO(t)
      d.append(dA) 

    
    return n,d


  #t= [0] * 46
  #t[12] = 0
  #t[11] = 0
  #t[10] = 0
  #t[9] = 0
  #t[8] = 0
  #t[7] = 0
  #t[6] = 0
  #sortCheck = [13,14,15,16,18,20]
  #n,d =  node5BinarySearchO(t)
  #print("n",n)
  #print("d", d)






  ################################################################################




  #estable nodo 4
  #En esta funcion agregamos 17,19

  def node4BinarySearch(t):

    sortCheck = [13,14,15,16,17,18,19,20]
    d = [] 

    if t[16] == 0:
      #print("node 16")
      d.append(16)
      
      if t[20] == 0:
        #print("node 20")
        d.append(20)
        n = 0
      
      elif t[20] == 1:
        #print("node 201")
        d.append(20)
        if t[18] == 0:
          #print("node 18")
          d.append(18)
          n = 20
        elif t[18] == 1:
          #print("node 18")
          d.append(18)
          n = 18
          if t[19] == 1:
            #print("node 19")  
            d.append(19)
            n = 19 



    elif t[16] ==1 :
      d.append(16)
      n = 16
      if t[13] == 1:
        d.append(13)
        n = 13
      elif t[13] == 0:
        d.append(13)
        if t[15] == 0:
          d.append(15)
          n = 16
          if t[17] == 1:
            #print("node 17")
            d.append(17)
            n = 17 
        elif t[15] == 1:
          d.append(15)
          if t[14] == 1:
            d.append(14)
            n= 14
          elif t[14] == 0:
            d.append(14)
            n = 15    
    return n,d

  #t= [0] * 46
  #t[13] = 0
  #t[14] = 0
  #t[15] = 0
  #t[17] = 0
  #t[16] = 0
  #t[18] = 0
  #t[19] = 0
  #t[20] = 0

  #n,d = node4BinarySearch(t)
  #print(n)
  #print(d)



  ################################################################################

  #Version estable de nodo3 usando busqueda lineal pero de saltos.
  # Ademas considera los nodos 23 y 22
  def node3BinarySearch(t):

    #sortCheck = [30,31,33,34,35]
    sortCheck = [25,24,23,22,26,27,28]

    nodesvisited = [] 

    if t[26] == 0:
      #print("node 26")
      nodesvisited.append(26)
      if t[28] == 1:
        #print("node 28")
        nodesvisited.append(28)
        if t[27] == 1:
          #print("node 27")
          nodesvisited.append(27)
          n = 27
        elif t[27] ==0:
          #print("node 27")
          nodesvisited.append(27)
          n = 28  
      elif t[28] == 0:
        #print("node 28")
        nodesvisited.append(28)
        n = 0
    elif t[26] == 1:
      #print("nodes 26")
      nodesvisited.append(26)
      if t[25] == 0:
        #print("nodes 25")
        nodesvisited.append(25)
        if t[24] == 0:
          #print("node 24")
          nodesvisited.append(24)
          n = 26
        elif t[24] == 1:
          #print("node 24")
          nodesvisited.append(24)
          n = 24
          if t[22] == 1:
            #print("node 22")
            nodesvisited.append(22)
            n = 22
          elif t[22] == 0:
            #print('node 22')
            nodesvisited.append(22)
            if t[23] == 1:
              #print("node 23")
              nodesvisited.append(23)
              n=23
            elif t[23] == 0:
              #print("node 23")
              nodesvisited.append(23)
              n = 24

      if t[25] == 1:
        #print("node 25")
        nodesvisited.append(25)  
        n = 25
    return n, nodesvisited



  #t= [0] * 46
  #t[25] = 0
  #t[22] = 0
  #t[23] = 0
  #t[24] = 0
  #t[26] = 0
  #t[27] = 0
  #t[28] = 0

  #n, nodesvisited =  node3BinarySearch(t)  
  #print(n)
  #print(nodesvisited)

  ################################################################################

  #Version estable de nodo2 usando busqueda lineal pero de saltos.
  # En esta  funcion consideramos al nodo 32
  
  def node2BinarySearch(t):

    sortCheck = [30,31,33,34,35]
    nodesvisited = [] 

    if t[33] == 0:
      #print("node 33")
      nodesvisited.append(33)
      if t[35] == 1:
        #print("node 35")
        nodesvisited.append(35)
        if t[34] == 1:
          #print("node 34")
          nodesvisited.append(34)
          n = 34
        elif t[34] ==0:
          #print("node 34")
          nodesvisited.append(34)
          n = 35  
      elif t[35] == 0:
        #print("node 35")
        nodesvisited.append(35)
        n = 0
    elif t[33] == 1:
      #print("nodes 33")
      nodesvisited.append(33)
      if t[30] == 0:
        #print("nodes 30")
        nodesvisited.append(30)
        if t[31] == 0:
          #print("node 30")
          nodesvisited.append(31)
          n = 33
        elif t[31] == 1:
          #print("node 31")
          nodesvisited.append(31)
          n = 31 
          if t[32] == 1:
            #print("node 32")
            nodesvisited.append(32)
            n = 32   
      if t[30] == 1:
        #print("node 30")
        nodesvisited.append(30)  
        n = 30
    return n, nodesvisited



  #t= [0] * 46
  #t[30] = 0
  #t[31] = 0
  #t[32] = 0
  #t[33] = 0
  #t[34] = 0
  #t[35] = 0

  #n, nodesvisited =  node2BinarySearch(t)  
  #print(n)
  #print(nodesvisited)



  ################################################################################



  #esta ya es una version estable del nodo 1
  # es la que vamos a usar. 
  #sortCheck = [39,38,43,41]


  def node1BinarySearch(t):
      
    sortCheck = [39,43,44]
    d = [] 
    n = 0

    if t[43] == 0:
      #print("node 43")
      d.append(43)
      if t[39] == 0:
        #print("node 39")
        d.append(39)
        n = 0
      elif t[39] == 1:
        #print("node 39")
        d.append(39)
        n = 39
        if t[37] == 1:
          #print("node 37")
          d.append(37)
          n = 37
        elif t[37] == 0:
          #print("node 37")
          d.append(37)
          if t[38] == 1:
            #print("nde 38")
            d.append(38)
            n = 38
          elif t[38] == 0:
            #print("nde 38")
            d.append(38)
            n = 39

    
    elif t[43] == 1:
      #print("node 43")
      d.append(43)
      if t[44] == 0:
        #print("node 43")
        d.append(44)
        n = 43
        if t[41] == 1:
          #print("node 41")
          d.append(41)
          if t[40] == 1:
            #print("node 40")
            d.append(40)
            n = 40
          elif t[40] == 0:
            #print("node 40")
            d.append(40)
            if t[42] == 1:
              #print("npde 42")
              d.append(42)
              n = 42
            elif t[42] == 0:
              #print("node 42")
              d.append(42)
              n = 41 
        elif t[41] == 0:
          #print("node 41")
          d.append(41)
          n = 43

      elif t[44] == 1:
        #print("node 44")
        d.append(44)
        n = 44  
      


    return n, d


  #t= [0] * 46
  #t[39] = 1
  #t[42] = 1
  #t[40] = 0
  #t[41] = 1
  #t[43] = 1
  #t[44] = 0
  #n,d = node1BinarySearch(t)
  #print(n)
  #print(d)




  def BinarySearchColector(t):
      
    sortCheck = [45,36,29,21,6]
    d = []
    n = 0

    if t[29] == 1:
      #print("node 29")
      d.append(29)
      if t[6] == 1:
        #print("node 6")
        d.append(6) 
        n = 6
      elif t[6] == 0:
        #print("node 6")
        d.append(6)
        if t[21] == 0:
          #print("node 6")
          d.append(21)
          n = 29
        elif t[21] ==1:
          #print("node 6")
          d.append(21)
          n = 21

    elif t[29] == 0:
      #print("node 29")
      d.append(29)
      
      if t[45] == 0:
        #print("node 45")
        d.append(45)
        n = 0
      elif t[45] == 1:
        #print("node 45")
        d.append(45)
        if t[36] == 0:
          #print("node 36")
          d.append(36) 
          n = 45
        elif t[36] == 1:
          #print("node 36")
          d.append(36)
          n = 36   

    return n,d


  #t = [0] * 46
  #t[45] = 0
  #t[36] = 0
  #t[29] = 0
  #t[21] = 0
  #t[6] = 0


  #n,d = BinarySearchColector(t)
  #print(n)
  #print(d)      



  def callNode(t):
    nT = []
    dT = []
    #n1,d1 = BinarySearchColector(t)
    #nT.append(n1)
    #dT.append(d1)
    n2 , d2 = node1BinarySearch(t)
    nT.append(n2)
    dT.append(d2)
    n3,d3 =  node2BinarySearch(t)  
    nT.append(n3)
    dT.append(d3)
    n4, d4 =  node3BinarySearch(t)  
    nT.append(n4)
    dT.append(d4)
    n5,d5 = node4BinarySearch(t)
    nT.append(n5)
    dT.append(d5)
    n6,d6 =  node5BinarySearchO(t)
    nT.append(n6)
    dT.append(d6)

    return nT, dT   

  #n = 6

  #n,d  = callNode(t)   
  #print(n)
  #print(d)

  nE,dE  = callNode(t)
  return nE,dE

n,d = callSearchpernode(t)
print(n)
print(d)
# Out:
# [0, 0, 0, 0, 8]
# [[43, 39], [33, 35], [26, 28], [16, 20], [4, [11, 9, 7, 8]]]

# %%
def BinarySearch(t,n):
    
  def BinarySearchColector(t):
      
    sortCheck = [45,36,29,21,6]
    d = []
    n = 0

    if t[29] == 1:
      #print("node 29")
      d.append(29)
      if t[6] == 1:
        #print("node 6")
        d.append(6) 
        n = 6
      elif t[6] == 0:
        #print("node 6")
        d.append(6)
        if t[21] == 0:
          #print("node 6")
          d.append(21)
          n = 29
        elif t[21] ==1:
          #print("node 6")
          d.append(21)
          n = 21

    elif t[29] == 0:
      #print("node 29")
      d.append(29)
      
      if t[45] == 0:
        #print("node 45")
        d.append(45)
        n = 46
      elif t[45] == 1:
        #print("node 45")
        d.append(45)
        if t[36] == 0:
          #print("node 36")
          d.append(36) 
          n = 45
        elif t[36] == 1:
          #print("node 36")
          d.append(36)
          n = 36   

    return n,d


  #t = [0] * 46
  #t[45] = 0
  #t[36] = 0
  #t[29] = 0
  #t[21] = 0
  #t[6] = 0


  #n,d = BinarySearchColector(t)
  #print(n)
  #print(d)


  #################################################################################
  #esta ya es una version estable del nodo 1
  # es la que vamos a usar. 
  #sortCheck = [39,38,43,41]


  def node1BinarySearch(t):
      
    sortCheck = [39,43,44]
    d = [] 
    n = 0

    if t[43] == 0:
      #print("node 43")
      d.append(43)
      if t[39] == 0:
        #print("node 39")
        d.append(39)
        n = 45
      elif t[39] == 1:
        #print("node 39")
        d.append(39)
        n = 39
        if t[37] == 1:
          #print("node 37")
          d.append(37)
          n = 37
        elif t[37] == 0:
          #print("node 37")
          d.append(37)
          if t[38] == 1:
            #print("nde 38")
            d.append(38)
            n = 38
          elif t[38] == 0:
            #print("nde 38")
            d.append(38)
            n = 39

    
    elif t[43] == 1:
      #print("node 43")
      d.append(43)
      if t[44] == 0:
        #print("node 43")
        d.append(44)
        n = 43
        if t[41] == 1:
          #print("node 41")
          d.append(41)
          if t[40] == 1:
            #print("node 40")
            d.append(40)
            n = 40
          elif t[40] == 0:
            #print("node 40")
            d.append(40)
            if t[42] == 1:
              #print("npde 42")
              d.append(42)
              n = 42
            elif t[42] == 0:
              #print("node 42")
              d.append(42)
              n = 41 
        elif t[41] == 0:
          #print("node 41")
          d.append(41)
          n = 43

      elif t[44] == 1:
        #print("node 44")
        d.append(44)
        n = 44  
      


    return n, d


  #t= [0] * 46
  #t[39] = 1
  #t[42] = 1
  #t[40] = 0
  #t[41] = 1
  #t[43] = 1
  #t[44] = 0
  #n,d = node1BinarySearch(t)
  #print(n)
  #print(d)

  ###############################################################################
  #Version estable de nodo2 usando busqueda lineal pero de saltos.
  # En esta  funcion consideramos al nodo 32
  
  def node2BinarySearch(t):

    sortCheck = [30,31,33,34,35]
    nodesvisited = [] 

    if t[33] == 0:
      #print("node 33")
      nodesvisited.append(33)
      n = 36
      if t[35] == 1:
        #print("node 35")
        nodesvisited.append(35)
        if t[34] == 1:
          #print("node 34")
          nodesvisited.append(34)
          n = 34
        elif t[34] ==0:
          #print("node 34")
          nodesvisited.append(34)
          n = 35  
      elif t[35] == 0:
        #print("node 35")
        nodesvisited.append(35)
        n = 36
    elif t[33] == 1:
      #print("nodes 33")
      nodesvisited.append(33)
      if t[30] == 0:
        #print("nodes 30")
        nodesvisited.append(30)
        if t[31] == 0:
          #print("node 30")
          nodesvisited.append(31)
          n = 33
        elif t[31] == 1:
          #print("node 31")
          nodesvisited.append(31)
          n = 31 
          if t[32] == 1:
            #print("node 32")
            nodesvisited.append(32)
            n = 32   
      if t[30] == 1:
        #print("node 30")
        nodesvisited.append(30)  
        n = 30
    return n, nodesvisited



  #t= [0] * 46
  #t[30] = 1
  #t[31] = 1
  #t[32] = 0
  #t[33] = 1
  #t[34] = 1
  #t[35] = 1

  #n, nodesvisited =  node2BinarySearch(t)  
  #print(n)
  #print(nodesvisited)

  ################################################################################
  #Version estable de nodo3 usando busqueda lineal pero de saltos.
  # Ademas considera los nodos 23 y 22
  def node3BinarySearch(t):

    #sortCheck = [30,31,33,34,35]
    sortCheck = [25,24,23,22,26,27,28]

    nodesvisited = [] 

    if t[26] == 0:
      #print("node 26")
      nodesvisited.append(26)
      n = 29
      if t[28] == 1:
        #print("node 28")
        nodesvisited.append(28)
        if t[27] == 1:
          #print("node 27")
          nodesvisited.append(27)
          n = 27
        elif t[27] ==0:
          #print("node 27")
          nodesvisited.append(27)
          n = 28  
      elif t[28] == 0:
        #print("node 28")
        nodesvisited.append(28)
        n = 29
    elif t[26] == 1:
      #print("nodes 26")
      nodesvisited.append(26)
      if t[25] == 0:
        #print("nodes 25")
        nodesvisited.append(25)
        if t[24] == 0:
          #print("node 24")
          nodesvisited.append(24)
          n = 26
        elif t[24] == 1:
          #print("node 24")
          nodesvisited.append(24)
          n = 24
          if t[22] == 1:
            #print("node 22")
            nodesvisited.append(22)
            n = 22
          elif t[22] == 0:
            #print('node 22')
            nodesvisited.append(22)
            if t[23] == 1:
              #print("node 23")
              nodesvisited.append(23)
              n=23
            elif t[23] == 0:
              #print("node 23")
              nodesvisited.append(23)
              n = 24

      if t[25] == 1:
        #print("node 25")
        nodesvisited.append(25)  
        n = 25
    return n, nodesvisited



  #t= [0] * 46
  #t[25] = 0
  #t[22] = 0
  #t[23] = 0
  #t[24] = 0
  #t[26] = 0
  #t[27] = 0
  #t[28] = 0

  #n, nodesvisited =  node3BinarySearch(t)  
  #print(n)
  #print(nodesvisited)
  



  #################################################################################
  #estable nodo 4
  #En esta funcion agregamos 17,19

  def node4BinarySearch(t):

    sortCheck = [13,14,15,16,17,18,19,20]
    d = [] 

    if t[16] == 0:
      #print("node 16")
      d.append(16)
      
      if t[20] == 0:
        #print("node 20")
        d.append(20)
        n = 21
      
      elif t[20] == 1:
        #print("node 201")
        d.append(20)
        if t[18] == 0:
          #print("node 18")
          d.append(18)
          n = 20
        elif t[18] == 1:
          #print("node 18")
          d.append(18)
          n = 18
          if t[19] == 1:
            #print("node 19")  
            d.append(19)
            n = 19 



    elif t[16] ==1 :
      d.append(16)
      n = 16
      if t[13] == 1:
        d.append(13)
        n = 13
      elif t[13] == 0:
        d.append(13)
        if t[15] == 0:
          d.append(15)
          n = 16
          if t[17] == 1:
            #print("node 17")
            d.append(17)
            n = 17 
        elif t[15] == 1:
          d.append(15)
          if t[14] == 1:
            d.append(14)
            n= 14
          elif t[14] == 0:
            d.append(14)
            n = 15    
    return n,d

  #t= [0] * 46
  #t[13] = 1
  #t[14] = 1
  #t[15] = 1
  #t[17] = 0
  #t[16] = 1
  #t[18] = 1
  #t[19] = 0
  #t[20] = 1

  #n,d = node4BinarySearch(t)
  #print(n)
  #print(d)






  ####################################################################################################################



  def node5ABinarySearchO(t):
    #Esta funcion es busqueda lineal 
    sortCheck = [4,3,2,1]
    val_l = 6
    d = []
    n = 0

    if t[3] == 0 :
      #print("node 3")
      d.append(3)
      if t[4] == 0:
        #print("node 4")
        d.append(4)
        n=6
      elif t[4] == 1:
        #print("node 4")
        d.append(4)
        n = 4 
        if t[5] == 1:
          #print("node 5")
          d.append(5)
          n = 5
        elif t[5] == 0:
          #print("node 5")
          d.append(5)
          n = 4  

    elif t[3] == 1:
      #print("node 3")
      d.append(3)
      if t[1] == 1:
        #print("node 1")
        d.append(1)
        n = 1
      elif t[1] == 0:
        #print("node 1")
        d.append(1)
        if t[2] == 0:
          #print("node 2")
          d.append(2)
          n = 3
        if t[2] == 1:
          #print("node 2")
          d.append(2)
          n = 2


    return n,d


  #t= [0] * 46
  #t[1] = 0
  #t[2] = 0
  #t[3] = 0
  #t[4] = 0
  #sortCheck = [13,14,15,16,18,20]
  #n,d =  node5ABinarySearchO(t)
  #print("n",n)
  #print("d", d)


  ###############################################################################

  #####################################################################3

  def node5BBinarySearchO(t):
    #Esta funcion es busqueda lineal 
    sortCheck = [9,11,12]
    val_l = 6
    d = []
    n = 0


    if t[11] == 0:
      #print("node 1")
      d.append(11)
      if t[9] == 0:
        #print("node 9")
        d.append(9)
        n = 6
      elif t[9] == 1:
        #print("node 9")
        d.append(9)
        n = 9
        if t[7] == 0:
          #print("ndde 7 ")
          d.append(7)
          if t[8] == 0:
            #print("npde 8")
            d.append(8)
            n = 9
          elif t[8] == 1:
            #print("node 8")
            d.append(8)
            n = 8
        elif t[7] == 1:
          #print("node 7")
          d.append(7)
          n = 7     

    
    elif t[11] == 1:
      #print("node 11")
      d.append(11)
      if t[12] == 1:
        #print("node 12")
        d.append(12)
        n = 12
      elif t[12] == 0:
        #print("node 12")
        d.append(12)
        n = 11
        if t[10] == 1:
          #print("node 10")
          d.append(10)
          n = 10
        elif t[10] == 0:
          #print("node 10")
          d.append(10)
          n = 11 


    return n,d


  #t= [0] * 46
  #t[9] = 0
  #t[11] = 0
  #t[12] = 0
  #sortCheck = [13,14,15,16,18,20]
  #n,d =  node5BBinarySearchO(t)
  #print("n",n)
  #print("d", d)


  #############################################################################



  def node5BinarySearchO(t):
    #Esta funcion es busqueda lineal 
    sortCheck = [6,4,9]
    val_l = sortCheck[0]
    d = []
    n = 0
    if t[4] == 0:
      #print("node 4")
      d.append(4)
      if t[9] == 0:
        #print("node 9")
        d.append(9)
        n = 6
      elif t[9] ==1:
        #print("node 9")
        n,dB =  node5BBinarySearchO(t)
        d.append(dB)
    elif t[4] == 1:
      n,dA =  node5ABinarySearchO(t)
      d.append(dA) 

    
    return n,d


  #t= [0] * 46
  #t[12] = 0
  #t[11] = 0
  #t[10] = 0
  #t[9] = 0
  #t[8] = 0
  #t[7] = 0
  #t[6] = 1
  #sortCheck = [13,14,15,16,18,20]
  #n,d =  node5BinarySearchO(t)
  #print("n",n)
  #print("d", d)



  def callNode(t,n):
    d = 0
    if n == 45:
      n , d = node1BinarySearch(t)
    elif n == 36:
      n, d =  node2BinarySearch(t)  
    elif n == 29:
      n, d =  node3BinarySearch(t)  
    elif n == 21:
      n,d = node4BinarySearch(t)
    elif n == 6:      
      n,d =  node5BinarySearchO(t)

    return n, d   

  #n = 6
  n,d  = callNode(t,n)   

  #print(n)
  #print(d)
  return n,d



n=1
n,d = BinarySearch(t,n)

# %%
def BinarySearchColector(t):
  sortCheck = [45,36,29,21,6]
  d = []
  n = 0

  if t[29] == 1:
    #print("node 29")
    d.append(29)
    if t[6] == 1:
      #print("node 6")
      d.append(6) 
      n = 6
    elif t[6] == 0:
      #print("node 6")
      d.append(6)
      if t[21] == 0:
        #print("node 6")
        d.append(21)
        n = 29
      elif t[21] ==1:
        #print("node 6")
        d.append(21)
        n = 21
  elif t[29] == 0:
    #print("node 29")
    d.append(29)
   
    if t[45] == 0:
      #print("node 45")
      d.append(45)
      n = 46
    elif t[45] == 1:
      #print("node 45")
      d.append(45)
      if t[36] == 0:
        #print("node 36")
        d.append(36) 
        n = 45
      elif t[36] == 1:
        #print("node 36")
        d.append(36)
        n = 36   

  return n,d


  #t = [0] * 46
  #t[45] = 0
  #t[36] = 0
  #t[29] = 0
  #t[21] = 0
  #t[6] = 0
