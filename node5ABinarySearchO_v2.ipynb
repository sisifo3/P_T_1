# %% [markdown]
# <a href="https://colab.research.google.com/github/sisifo3/P_T_1/blob/main/node5ABinarySearchO_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
####################################################################################################################



def node5ABinarySearchO(t):
  #Esta funcion es busqueda lineal 
  sortCheck = [4,3,2,1]
  val_l = 6
  d = []
  n = 0

  if t[3] == 0 :
    print("node 3")
    d.append(3)
    if t[4] == 0:
      print("node 4")
      d.append(4)
      n=6
    elif t[4] == 1:
      print("node 4")
      d.append(4)
      n = 4 
      if t[5] == 1:
        print("node 5")
        d.append(5)
        n = 5
      elif t[5] == 0:
        print("node 5")
        d.append(5)
        n = 4  

  elif t[3] == 1:
    print("node 3")
    d.append(3)
    if t[1] == 1:
      print("node 1")
      d.append(1)
      n = 1
    elif t[1] == 0:
      print("node 1")
      d.append(1)
      if t[2] == 0:
        print("node 2")
        d.append(2)
        n = 3
      if t[2] == 1:
        print("node 2")
        d.append(2)
        n = 2


  return n,d


t= [0] * 46
t[1] = 0
t[2] = 0
t[3] = 0
t[4] = 0
#sortCheck = [13,14,15,16,18,20]
n,d =  node5ABinarySearchO(t)
print("n",n)
print("d", d)


###############################################################################

#####################################################################3

def node5BBinarySearchO(t):
  #Esta funcion es busqueda lineal 
  sortCheck = [9,11,12]
  val_l = 6
  d = []
  n = 0


  if t[11] == 0:
    print("node 1")
    d.append(11)
    if t[9] == 0:
      print("node 9")
      d.append(9)
      n = 6
    elif t[9] == 1:
      print("node 9")
      d.append(9)
      n = 9
      if t[7] == 0:
        print("ndde 7 ")
        d.append(7)
        if t[8] == 0:
          print("npde 8")
          d.append(8)
          n = 9
        elif t[8] == 1:
          print("node 8")
          d.append(8)
          n = 8
      elif t[7] == 1:
        print("node 7")
        d.append(7)
        n = 7     

   
  elif t[11] == 1:
    print("node 11")
    d.append(11)
    if t[12] == 1:
      print("node 12")
      d.append(12)
      n = 12
    elif t[12] == 0:
      print("node 12")
      d.append(12)
      n = 11
      if t[10] == 1:
        print("node 10")
        d.append(10)
        n = 10
      elif t[10] == 0:
        print("node 10")
        d.append(10)
        n = 11 


  return n,d


t= [0] * 46
t[9] = 0
t[11] = 0
t[12] = 0
#sortCheck = [13,14,15,16,18,20]
n,d =  node5BBinarySearchO(t)
print("n",n)
print("d", d)


#############################################################################



def node5BinarySearchO(t):
  #Esta funcion es busqueda lineal 
  sortCheck = [6,4,9]
  val_l = sortCheck[0]
  d = []
  n = 0
  if t[4] == 0:
    print("node 4")
    d.append(4)
    if t[9] == 0:
      print("node 9")
      d.append(9)
      n = 6
    elif t[9] ==1:
      print("node 9")
      n,dB =  node5BBinarySearchO(t)
      d.append(dB)
  elif t[4] == 1:
    n,dA =  node5ABinarySearchO(t)
    d.append(dA) 

  
  return n,d


t= [0] * 46
t[12] = 0
t[11] = 0
t[10] = 0
t[9] = 0
t[8] = 0
t[7] = 0
t[6] = 1
#sortCheck = [13,14,15,16,18,20]
n,d =  node5BinarySearchO(t)
print("n",n)
print("d", d)
# Out:
# node 3
# node 4
# n 6
# d [3, 4]
# node 1
# node 9
# n 6
# d [11, 9]
# node 4
# node 9
# n 6
# d [4, 9]
